# %% [markdown]
# Telco Customer Churn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\DataPy\Customer Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #Replacing blanks with 0 and no total charge

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ",0)
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Overall sum
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#primary key- unique values check
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Converted value 0 and 1 of senior citizen to yes/no to make it readable

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "no"
df["SeniorCitizen"] = df["SeniorCitizen"].apply(conv)

# %%
df.head(30)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            no     Yes         No       1           No
# 1   5575-GNVDE    Male            no      No         No      34          Yes
# 2   3668-QPYBK    Male            no      No         No       2          Yes
# 3   7795-CFOCW    Male            no      No         No      45           No
# 4   9237-HQITU  Female            no      No         No       2          Yes
# 5   9305-CDSKC  Female            no      No         No       8          Yes
# 6   1452-KIOVK    Male            no      No        Yes      22          Yes
# 7   6713-OKOMC  Female            no      No         No      10           No
# 8   7892-POOKP  Female            no     Yes         No      28          Yes
# 9   6388-TABGU    Male            no      No        Yes      62          Yes
# 10  9763-GRSKD    Male            no     Yes        Yes      13          Yes
# ...

# %%
# why customer stop using our products, characteristics of customer
sns.countplot( x = "Churn", data = df)
plt.show()

# %%
#label with values
ax = sns.countplot( x = "Churn", data = df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
#label with values in percentages
gb = df.groupby("Churn").agg({"Churn":"count"})
gb
#plt.pie(df["Churn"])
#plt.show()
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.pie(gb["Churn"])
plt.show()

# %%
plt.pie(gb["Churn"], labels = gb.index, autopct = "%1.2f%%")
plt.show()

# %%
plt.figure(figsize = (3,4))
plt.pie(gb["Churn"], labels = gb.index, autopct = "%1.2f%%")
plt.title("Percentage of Customer Churn", fontsize = 10)
plt.show()

# %%
#label with title
ax = sns.countplot( x = "Churn", data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of customer by Churn")
plt.show()

# %% [markdown]
# #From pie chart we can conclued that 26.54% of our customer has churned out now let's explore reason behind it

# %%
plt.figure(figsize = (4,4))
sns.countplot(x = 'gender', data = df, hue = "Churn")   #gender customers
plt.title("Churn By Gender")
plt.show()

# %%
plt.figure(figsize = (4,4))
sns.countplot(x = 'SeniorCitizen', data = df, hue = "Churn")   #gender customers
plt.title("Churn By SeniorCitizen")
plt.show()

# %%
total_counts = df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True).unstack() * 100

# plot
fig, ax = plt.subplots(figsize=(6, 6))  # adjusted figsize for better visualization

# plot bars
total_counts.plot(
    kind='bar',
    stacked=True,
    ax=ax,
    color=['#1f77b4', '#ff7f0e']
)

# Add percentage labels on bars
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()

    if height > 0:
        ax.text(
            x + width / 2,
            y + height / 2,
            f'{height:.1f}%',
            ha='center',
            va='center'
        )

plt.title('Churn by Senior Citizen (Stacked Bar Chart)')
plt.xlabel('SeniorCitizen')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)

plt.legend(title="Churn", loc='upper right')  # fixed legend spelling

plt.show()

# %%
#percentage
plt.figure(figsize = (3,3))
ax = sns.countplot(x = 'SeniorCitizen', data = df) #gender customers
ax.bar_label(ax.containers[0])
plt.title("Count of Customers By SeniorCitizen")
plt.show()

# %% [markdown]
# #comparative a greater percentage of people in senior citizen category have churned

# %%
total_counts = df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True).unstack() * 100

# plot
fig, ax = plt.subplots(figsize=(6, 6))  # adjusted figsize for better visualization

# plot bars
total_counts.plot(
    kind='bar',
    stacked=True,
    ax=ax,
    color=['#1f77b4', '#ff7f0e']
)

# Add percentage labels on bars
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()

    if height > 0:
        ax.text(
            x + width / 2,
            y + height / 2,
            f'{height:.1f}%',
            ha='center',
            va='center'
        )

plt.title('Churn by Senior Citizen (Stacked Bar Chart)')
plt.xlabel('SeniorCitizen')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)

plt.legend(title="Churn", bbox_to_anchor = (0.9,0.9))  # Customize legend location

plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = 'tenure', data = df, bins= 50)   #tenure
plt.title("Churn by Tenure")
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = 'tenure', data = df, bins= 50)   #tenure
plt.title("Churn by Tenure")
plt.show()

# %% [markdown]
# #People who have use used our services for a long time have stayed and people who have used output
# #1 or 2 months have churn

# %%
plt.figure(figsize = (4,4))
ax = sns.histplot(x = 'Contract', data = df)   #contracts
ax.bar_label(ax.containers[0])
plt.title("Count of Customers by Contracts")
plt.show()

# %%
plt.figure(figsize = (4,4))
ax = sns.histplot(x = 'Contract', data = df, hue = "Churn")   #contracts
ax.bar_label(ax.containers[0])
plt.title("Count of Customers by Contracts")
plt.show()

# %% [markdown]
# #people who have month to month contact likely to churn then from those who have 1 or 2 years or contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# figure size (increase because many plots)
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))

axes = axes.flatten()

for i, col in enumerate(cols):
    sns.countplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f'Churn by {col}')
    axes[i].tick_params(axis='x', rotation=30)

# remove empty subplot (if any)
for j in range(len(cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# figure size (increase because many plots)
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))

axes = axes.flatten()

for i, col in enumerate(cols):
    sns.countplot(data=df, x=col, ax=axes[i], hue='Churn')
    axes[i].set_title(f'Churn by {col}')
    axes[i].tick_params(axis='x', rotation=30)

# remove empty subplot (if any)
for j in range(len(cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #The plots show that customers with OnlineSecurity, TechSupport, and DeviceProtection enabled have significantly lower churn rates, indicating strong retention impact from support-related services.
# Conversely, customers without these services show a much higher proportion of churn, especially where “No internet service” or “No” is present.
# Streaming services (TV and Movies) show a relatively balanced churn pattern, suggesting weaker influence on retention

# %%
plt.figure(figsize = (4,6))
ax = sns.countplot(x = "PaymentMethod", data = df, hue = "Churn")   
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Churned Customers by Payment Methods")
plt.xticks(rotation = 45)  #degree labels
plt.show()

# %% [markdown]
# #customer is likely to churn when he is using electronic check as a Payment Method
